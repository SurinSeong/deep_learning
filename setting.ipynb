# %%
# import tensorflow as tf
# if tf.test.is_gpu_available():
#     print("GPU가 사용 가능한 환경입니다. 현재 GPU:", tf.test.gpu_device_name())
# else:
#     print("GPU를 사용할 수 없는 환경입니다.")
# print(tf.__version__)
# print(tf.config.list_physical_devices('GPU'))
# Out:
# WARNING:tensorflow:From C:\Users\tjdtn\AppData\Local\Temp\ipykernel_37756\2520132896.py:2: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.
# GPU를 사용할 수 없는 환경입니다.
# 2.10.0
# []
